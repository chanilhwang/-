# %%
# !python --version
# Out:
# Python 3.7.14

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.6 LTS

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   37G   71G  35% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.1G  910M  54% /sbin/docker-init
# tmpfs           6.4G   36K  6.4G   1% /var/colab
# /dev/sda1        80G   38G   42G  48% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0

# %%
# !head /proc/meminfo
# Out:
# MemTotal:       13297228 kB
# MemFree:        10907912 kB
# MemAvailable:   12474876 kB
# Buffers:           62064 kB
# Cached:          1662352 kB
# SwapCached:            0 kB
# Active:           522712 kB
# Inactive:        1695836 kB
# Active(anon):        972 kB
# Inactive(anon):   449376 kB

# %%
# !nvidia-smi

# %%
#tesorflow version
import tensorflow as tf
print(tf.__version__)

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(10, 5))
df.to_csv("/content/drive/MyDrive/colab_test/dfs.csv")

#!ls -Fcal '/content/drive/MyDrive/colab_test'

pd.read_csv('/content/drive/MyDrive/colab_test/dfs.csv')

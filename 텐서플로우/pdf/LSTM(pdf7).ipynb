# %%
#LSTM
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#LSTM
model.add(LSTM(units = 64, input_shape = (28, 28)))
#FC
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                23808
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 24,458
# Trainable params: 24,458
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1500/1500 [==============================] - 24s 14ms/step - loss: 0.4849 - accuracy: 0.8453 - val_loss: 0.1742 - val_accuracy: 0.9468
# Epoch 2/5
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.1547 - accuracy: 0.9546 - val_loss: 0.1135 - val_accuracy: 0.9663
# Epoch 3/5
# 1500/1500 [==============================] - 28s 19ms/step - loss: 0.1079 - accuracy: 0.9674 - val_loss: 0.0886 - val_accuracy: 0.9749
# Epoch 4/5
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0834 - accuracy: 0.9754 - val_loss: 0.0830 - val_accuracy: 0.9734
# Epoch 5/5
# 1500/1500 [==============================] - 26s 18ms/step - loss: 0.0697 - accuracy: 0.9790 - val_loss: 0.0789 - val_accuracy: 0.9758

# %%
#predict, evaluate
import numpy as np

labels = model.predict(test_images)

print("Accuracy : %4f" %(model.evaluate(test_images, one_hot_test_labels)[1]))

fig = plt.figure()
for i in range(10):
  subplot = fig.add_subplot(2, 5, i + 1)
  subplot.set_xticks([])
  subplot.set_yticks([])
  subplot.set_title('%d' %(np.argmax(labels[i])))
  subplot.imshow(test_images[i].reshape(28, 28), cmap = 'gray')
plt.show()

# %%
#LSTM, return sequences = true
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#LSTM
model.add(LSTM(units = 64, return_sequences = True, input_shape = (28, 28)))
#Flatten
model.add(Flatten())
#FC
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 28, 64)            23808
#
#  flatten (Flatten)           (None, 1792)              0
#
#  dense_1 (Dense)             (None, 10)                17930
#
# =================================================================
# Total params: 41,738
# Trainable params: 41,738
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1500/1500 [==============================] - 26s 16ms/step - loss: 0.2670 - accuracy: 0.9191 - val_loss: 0.1121 - val_accuracy: 0.9659
# Epoch 2/5
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0874 - accuracy: 0.9735 - val_loss: 0.0741 - val_accuracy: 0.9763
# Epoch 3/5
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0637 - accuracy: 0.9797 - val_loss: 0.0636 - val_accuracy: 0.9801
# Epoch 4/5
# 1500/1500 [==============================] - 24s 16ms/step - loss: 0.0474 - accuracy: 0.9853 - val_loss: 0.0529 - val_accuracy: 0.9839
# Epoch 5/5
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0384 - accuracy: 0.9881 - val_loss: 0.0516 - val_accuracy: 0.9843

# %%
#GRU, return sequences = true
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM, GRU
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#LSTM
model.add(GRU(units = 64, return_sequences = True, input_shape = (28, 28)))
#Flatten
model.add(Flatten())
#FC
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 28, 64)            18048
#
#  flatten_1 (Flatten)         (None, 1792)              0
#
#  dense_2 (Dense)             (None, 10)                17930
#
# =================================================================
# Total params: 35,978
# Trainable params: 35,978
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.2587 - accuracy: 0.9231 - val_loss: 0.1048 - val_accuracy: 0.9678
# Epoch 2/5
# 1500/1500 [==============================] - 19s 13ms/step - loss: 0.0873 - accuracy: 0.9729 - val_loss: 0.0751 - val_accuracy: 0.9773
# Epoch 3/5
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0604 - accuracy: 0.9817 - val_loss: 0.0656 - val_accuracy: 0.9809
# Epoch 4/5
# 1500/1500 [==============================] - 20s 13ms/step - loss: 0.0472 - accuracy: 0.9856 - val_loss: 0.0556 - val_accuracy: 0.9843
# Epoch 5/5
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0399 - accuracy: 0.9875 - val_loss: 0.0540 - val_accuracy: 0.9844

# %%
#bidirectional, simple rnn
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM, Bidirectional
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#Simple RNN
model.add(Bidirectional(SimpleRNN(units = 64, return_sequences = True), input_shape = (28, 28)))
#Flatten  
model.add(Flatten())
#FC
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_2 (Bidirectio  (None, 28, 128)          11904
#  nal)
#
#  flatten_3 (Flatten)         (None, 3584)              0
#
#  dense_3 (Dense)             (None, 10)                35850
#
# =================================================================
# Total params: 47,754
# Trainable params: 47,754
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.2622 - accuracy: 0.9220 - val_loss: 0.1718 - val_accuracy: 0.9474
# Epoch 2/5
# 1500/1500 [==============================] - 28s 19ms/step - loss: 0.1423 - accuracy: 0.9580 - val_loss: 0.1416 - val_accuracy: 0.9605
# Epoch 3/5
# 1500/1500 [==============================] - 28s 18ms/step - loss: 0.1076 - accuracy: 0.9690 - val_loss: 0.1378 - val_accuracy: 0.9628
# Epoch 4/5
# 1500/1500 [==============================] - 28s 19ms/step - loss: 0.0969 - accuracy: 0.9723 - val_loss: 0.1225 - val_accuracy: 0.9697
# Epoch 5/5
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0890 - accuracy: 0.9755 - val_loss: 0.1332 - val_accuracy: 0.9660

# %%
#bidirectional LSTM, return sequences = true
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM, Bidirectional
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#LSTM
model.add(Bidirectional(LSTM(units = 64, return_sequences = True), input_shape = (28, 28)))
#Flatten
model.add(Flatten())
#FC
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)

# %%
#bidirectional GRU, return sequences = true
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM, GRU, Bidirectional
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#LSTM
model.add(Bidirectional(GRU(units = 64, return_sequences = True), input_shape = (28, 28)))
#Flatten
model.add(Flatten())
#FC
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)

# %%
#bidirectional LSTM, return sequences = true
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from keras.datasets.mnist import load_data
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Flatten, LSTM, Bidirectional
from keras.optimizers import Adam

(train_images, train_labels), (test_images, test_labels) = load_data()

train_images = train_images / 255.0
test_images = test_images / 255.0

one_hot_train_labels = to_categorical(train_labels, 10)
one_hot_test_labels = to_categorical(test_labels, 10)

#model
model = Sequential()
#LSTM
model.add(Bidirectional(LSTM(units = 64, return_sequences = True), input_shape = (28, 28)))
model.add(Bidirectional(LSTM(units = 64, return_sequences = True)))
model.add(Bidirectional(LSTM(units = 64, return_sequences = True)))
#Flatten
model.add(Flatten())
#FC
model.add(Dense(128, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

#compile
model.compile(
    optimizer = Adam(0.001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
    )
#summary
model.summary()
#fit
history = model.fit(train_images, one_hot_train_labels, epochs = 5, batch_size = 32, validation_split = 0.2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirectio  (None, 28, 128)          47616
#  nal)
#
#  bidirectional_5 (Bidirectio  (None, 28, 128)          98816
#  nal)
#
#  bidirectional_6 (Bidirectio  (None, 28, 128)          98816
#  nal)
#
#  flatten_1 (Flatten)         (None, 3584)              0
#
#  dense_1 (Dense)             (None, 128)               458880
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 713,034
# Trainable params: 713,034
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1500/1500 [==============================] - 31s 16ms/step - loss: 0.2613 - accuracy: 0.9163 - val_loss: 0.1029 - val_accuracy: 0.9682
# Epoch 2/5
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0860 - accuracy: 0.9739 - val_loss: 0.0821 - val_accuracy: 0.9753
# Epoch 3/5
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0619 - accuracy: 0.9806 - val_loss: 0.0619 - val_accuracy: 0.9821
# Epoch 4/5
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0465 - accuracy: 0.9855 - val_loss: 0.0564 - val_accuracy: 0.9837
# Epoch 5/5
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0403 - accuracy: 0.9880 - val_loss: 0.0462 - val_accuracy: 0.9869
